# %% [markdown]
# # Space Py Quest
# ## The Python-Based Gravitational-Wave Detector Game

# %% [markdown]
# Welcome to Space-Py Quest! The aim of the game is simple: detect as many gravitational waves as you can, without blowing your budget.
#
# Run ```stq = spaceTimeQuest()``` to start the game, and run ```stq.tabs``` to show the controls. The game will start with random detector paramaters. Your job is to imrpove the detectors. You can alos start the game with a dictionary of parameters, for example to plot the sensitiivity of Advanced LIGO (aLIGO).

# %%
import pystq.widget as widget
from pystq.widget import spaceTimeQuest
import pystq.materials as materials
import pystq.sites as sites

aLIGO = {
    'depth' : 0,
    'pumps' : 6,
    'sus_stages' : 4,
    'sus_length' : 0.5,
    'mirror_mass' : 40,
    'power' : 125,
    'roughness' : 100,
    'site' : sites.Desert,
    'material' : materials.Silica,
    'temperature' : 290,
}

# %% [markdown]
# Use the widgets to adjust the detector's configuration. This will change its sensitivity curves on the noise plot below. When you think it's as sensitive as it can be, find the 'Science Run' button widget to see how many detections you make! Can you stay within your budget?

# %%
stq = spaceTimeQuest(aLIGO)
stq.tabs
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="41d4983e-9a97-4d16-ad26-3f7d162d12e2"></div>
# </div>
# Tab(children=(VBox(children=(HBox(children=(interactive(children=(Checkbox(value=True, description='Residual Gas'), Output()), _dom_classes=('widget-interact',)),)), HBox(children=(interactive(children=(Checkbox(value=True, description='Mirror Thermal'), Output()), _dom_classes=('widget-interact',)), interactive(children=(Checkbox(value=True, description='Radiation Pressure'), Output()), _dom_classes=('widget-interact',)))), HBox(children=(interactive(children=(Checkbox(value=True, description='Seismic'), Output()), _dom_classes=('widget-interact',)), interactive(children=(Checkbox(value=True, description='Shot'), Output()), _dom_classes=('widget-interact',)))), HBox(children=(interactive(children=(Checkbox(value=True, description='Gravity Gradient'), Output()), _dom_classes=('widget-interact',)), interactive(children=(Checkbox(value=True, description='Suspension Thermal'), Output()), _dom_classes=('widget-interact',)))))), interactive(children=(FloatRangeSlider(value=(-25.0, -21.0), continuous_update=False, description=' ', max=-18.0, min=-27.0, readout_format='', step=1.0), Output()), _dom_classes=('widget-interact',)), Button(description='Run', icon='check', style=ButtonStyle(), tooltip='Science Run'), interactive(children=(FloatRangeSlider(value=(0.0, 4.0), continuous_update=False, description=' ', max=5.0, min=-4.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(ToggleButtons(description=' ', index=2, options=('City', 'Jungle', 'Desert', 'Island'), value='Desert'), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=0.0, continuous_update=False, description=' ', max=1000.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=6.0, continuous_update=False, description=' ', max=16.0, min=1.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=290.0, continuous_update=False, description=' ', max=330.0, min=1.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=4.0, continuous_update=False, description=' ', max=9.0, min=1.0, readout_format='', step=1.0), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=0.5, continuous_update=False, description=' ', max=5.0, min=0.35, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=40.0, continuous_update=False, description=' ', min=5.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=125.0, continuous_update=False, description=' ', max=200.0, min=1.0, readout_format=''), Output()), _dom_classes=('widget-interact',)), interactive(children=(ToggleButtons(description=' ', index=3, options=('Crystal', 'Silicon', 'Sapphire', 'Silica'), value='Silica'), Output()), _dom_classes=('widget-interact',)), interactive(children=(FloatSlider(value=100.0, continuous_update=False, description=' ', max=500.0, min=1.0, readout_format=''), Output()), _dom_classes=('widget-interact',))), _titles={'0': 'Noise Curve Options', '1': 'h-range [1/√Hz]', '2': 'Science Run', '3': 'Frequency range [loq(Hz)]', '4': 'Location', '5': 'Depth [m]', '6': 'No. vacuum pumps', '7': 'Temperature [K]', '8': 'No. suspension stages', '9': 'Suspension length [m]', '10': 'Mirror mass [kg]', '11': 'Laser power [W]', '12': 'Material', '13': 'Roughness [nm]'})

# %% [markdown]
# Another set of examples parameters is shown below. This is somewhat similar to the LIGO Voyager upgrade plan.

# %%
Voyager = {
    'depth' : 0,
    'pumps' : 8,
    'sus_stages' : 4,
    'sus_length' : 0.5,
    'mirror_mass' : 80,
    'power' : 150,
    'roughness' : 10,
    'site' : sites.Desert,
    'material' : materials.Silicon,
    'temperature' : 295,
}
